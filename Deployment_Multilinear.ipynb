# %%
import pickle

# %%
loaded_model=pickle.load(open("Finalized_model_Mul_linear.sav",'rb'))
result=loaded_model.predict([[1234,789,6543,0,0]])
# Out:
# C:\Users\gayut\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[43606.38746929]])
