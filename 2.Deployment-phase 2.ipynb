# %%
#Step 1
# We are opening the ickle file
import pickle

# %%
#Step 2
#We are loading the trained model and check the output in end user prespective, here the user has entered 0 years as the exp
loaded_model=pickle.load(open("Finalized_model_linear.sav",'rb'))
result=loaded_model.predict([[0]])
# Out:
# C:\Users\gayut\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Step 3
#We are executing the result and it has displayed the predicted salary below
#It has produced the orgin value as the predicted o
result
# Out:
# array([[26777.3913412]])
